# %%
from langgraph.graph import StateGraph
from langgraph.graph import START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()  # reads GOOGLE_API_KEY from .env file

# Initialize the Gemini model
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state["title"]
    prompt = f"Generate a detailed outline for a blog on the topic: {title}"
    response = model.invoke(prompt)
    state["outline"] = response.content
    return state

def create_blog(state: BlogState) -> BlogState:
    title = state["title"]
    outline = state["outline"]
    prompt = f"Write a detailed blog on the title: {title}\nUsing the following outline:\n{outline}"
    response = model.invoke(prompt)
    state["content"] = response.content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)

graph.add_edge(START, "create_outline")
graph.add_edge("create_outline", "create_blog")
graph.add_edge("create_blog", END)

workflow = graph.compile()

# %%
initial_state = {"title": "Rise of AI in India"}
final_state = workflow.invoke(initial_state)

# %%
print(final_state["outline"])   # intermediate output — still accessible
# Out:
# Here's a detailed outline for a blog post on the "Rise of AI in India," designed to be comprehensive, engaging, and structured for a blog format.
#
# ---
#
# ## Blog Title Ideas:
# *   India's AI Awakening: A Deep Dive into the Nation's Tech Revolution
# *   From Digital Divide to AI Drive: Tracing India's AI Ascent
# *   The AI Bharat Story: How India is Redefining the Global AI Landscape
# *   Unlocking Potential: The Multifaceted Rise of AI in India
# *   Beyond the Hype: Understanding India's Strategic Embrace of AI
#
# ---
#
# ## Blog Outline: The Rise of AI in India
#
# **Target Audience:** Tech enthusiasts, policymakers, investors, entrepreneurs, students, general public interested in India's technological advancements.
# **Tone:** Informative, optimistic, analytical, slightly visionary.
#
# ---
#
# ### **I. Introduction (Approx. 15% of total word count)**
#
# *   **A. Catchy Hook:**
#     *   Start with a global statement about AI's transformative power, then pivot to India's unique position.
#     *   Example: "While AI reshapes industries worldwide, a silent revolution is brewing in the heart of the world's largest democracy – India."
# *   **B. Setting the Stage: India's Digital Leap:**
#     *   Briefly mention India's journey from a traditional economy to a digital powerhouse (UPI, Aadhaar, smartphone penetration).
#     *   Highlight the existing robust IT services industry and a massive talent pool as foundational strengths.
# *   **C. Thesis Statement:**
#     *   Clearly state the blog's purpose: To explore the multifaceted rise of AI in India, examining its key drivers, diverse applications, the thriving ecosystem, inherent challenges, and its immense future potential on both national and global scales.
#
# ### **II. The Catalysts: Why Now? (Approx. 20%)**
#
# *   **A. Government Push & Policy Framework:**
#     *   **"AI for All" Vision:** NITI Aayog's national strategy, focus on inclusive growth.
#     *   **Key Initiatives:** National Programme on AI, Responsible AI for Youth, Data Protection Bill (and its implications).
#     *   **Funding & Infrastructure:** Efforts to build compute infrastructure and data centers.
# *   **B. A Deep & Diverse Talent Pool:**
#     *   **STEM Graduates:** India's vast number of engineering and science graduates.
#     *   **IT Services Legacy:** Strong foundation in software development, data management.
#     *   **Upskilling & Reskilling:** Growth of AI/ML courses, certifications, and corporate training programs.
# *   **C. Data-Rich Environment:**
#     *   **Digital Transformation:** UPI, Aadhaar, Jio's internet penetration generating vast datasets.
#     *   **Language Diversity:** Unique challenge and opportunity for multilingual AI.
#     *   **Domain-Specific Data:** Healthcare, agriculture, finance generating unique insights.
# *   **D. Thriving Startup Ecosystem & Investment:**
#     *   **Venture Capital Influx:** Growing interest from domestic and international investors in Indian AI startups.
#     *   **Incubation & Accelerators:** Government-backed and private programs fostering innovation.
#     *   **Success Stories:** Mention a few prominent Indian AI startups (e.g., in SaaS, healthcare, fintech).
#
# ### **III. AI in Action: Sectoral Impact & Applications (Approx. 25%)**
#
# *   **A. Healthcare Transformation:**
#     *   **Diagnostics:** AI-powered image analysis (radiology, pathology), early disease detection.
#     *   **Drug Discovery & Development:** Accelerating research, personalized medicine.
#     *   **Telemedicine & Remote Care:** Bridging urban-rural healthcare gaps, predictive analytics for outbreaks.
# *   **B. Revolutionizing Agriculture (Agri-Tech):**
#     *   **Precision Farming:** Crop yield prediction, pest and disease detection, soil analysis.
#     *   **Supply Chain Optimization:** Reducing waste, improving market access for farmers.
#     *   **Weather Forecasting & Advisory:** AI-driven insights for farmers.
# *   **C. Financial Services (FinTech):**
#     *   **Fraud Detection & Risk Assessment:** Real-time anomaly detection, credit scoring for underserved populations.
#     *   **Personalized Banking:** Chatbots, customized financial advice.
#     *   **Algorithmic Trading & Investment:** AI-driven insights for markets.
# *   **D. Education & Skilling:**
#     *   **Personalized Learning:** Adaptive platforms, intelligent tutoring systems.
#     *   **Content Creation & Curation:** AI-assisted educational material development.
#     *   **Administrative Efficiency:** Automating tasks for educators.
# *   **E. Language & Localization:**
#     *   **Multilingual AI:** Developing models for India's diverse languages (voice assistants, translation).
#     *   **Natural Language Processing (NLP):** Enhancing customer service, content moderation.
# *   **F. Smart Cities & Public Services:**
#     *   **Traffic Management:** Predictive analytics for congestion, smart signaling.
#     *   **Waste Management:** Optimization, resource allocation.
#     *   **Grievance Redressal:** AI-powered chatbots for citizen services.
#
# ### **IV. The Ecosystem & Key Players (Approx. 10%)**
#
# *   **A. Startups & Innovators:**
#     *   Highlight their agility in addressing specific Indian problems.
#     *   Mention key innovation hubs (Bengaluru, Hyderabad, Gurugram, Pune).
# *   **B. Corporate Giants:**
#     *   Role of IT service companies (TCS, Infosys, Wipro) in AI adoption and solution development.
#     *   Contribution of conglomerates (Reliance, Tata Group) in integrating AI across their diverse businesses.
# *   **C. Academia & Research Institutions:**
#     *   IITs, IISc, and other universities driving fundamental research and talent development.
#     *   Formation of dedicated AI labs and centers of excellence.
# *   **D. International Collaborations:**
#     *   Partnerships with global tech giants and research institutions.
#     *   Foreign direct investment in Indian AI.
#
# ### **V. Challenges & Ethical Considerations (Approx. 15%)**
#
# *   **A. Data Quality & Availability:**
#     *   Issues with fragmented, unstructured, or biased data.
#     *   Need for better data governance and standardization.
# *   **B. Infrastructure & Compute Power:**
#     *   Access to high-performance computing, particularly for smaller startups.
#     *   Reliable connectivity in rural areas.
# *   **C. Talent Gap & Upskilling:**
#     *   Shortage of specialized AI researchers and engineers.
#     *   Need for continuous upskilling of the existing workforce.
# *   **D. Ethical AI & Bias:**
#     *   Addressing algorithmic bias in diverse populations.
#     *   Ensuring fairness, transparency, and accountability in AI systems.
#     *   Privacy concerns and data security.
# *   **E. Regulatory Framework:**
#     *   Developing comprehensive and agile regulations that foster innovation while ensuring safety.
# *   **F. Job Displacement vs. Creation:**
#     *   Managing the societal impact of automation, focusing on new job creation.
#
# ### **VI. The Road Ahead: India's AI Future (Approx. 10%)**
#
# *   **A. "AI for Bharat":**
#     *   Focus on solving India-specific problems (e.g., poverty, healthcare access, climate resilience).
#     *   Leveraging AI for inclusive growth and social impact.
# *   **B. Global AI Leadership:**
#     *   India's potential to become a global hub for AI innovation, particularly in responsible and ethical AI.
#     *   Exporting AI solutions and expertise to developing nations.
# *   **C. Emerging Technologies:**
#     *   Integration with Quantum Computing, IoT, Web3.0.
#     *   Focus on Explainable AI (XAI) and Trustworthy AI.
# *   **D. Policy Evolution:**
#     *   Continued government support, agile policy-making, and public-private partnerships.
#
# ### **VII. Conclusion (Approx. 5%)**
#
# *   **A. Recap:** Briefly summarize India's unique position, key drivers, and diverse applications of AI.
# *   **B. Reinforce Thesis:** Reiterate India's transformative journey and its potential to shape the global AI narrative.
# *   **C. Forward-Looking Statement/Call to Action:**
#     *   End with an inspiring vision of India as a responsible AI leader.
#     *   Encourage continued innovation, collaboration, and ethical development.
#     *   "The rise of AI in India isn't just a technological leap; it's a societal transformation poised to redefine the future for a billion people and beyond."
#
# ---
#
# ### **Potential Visuals/Multimedia:**
# *   Infographics on AI investment in India, sectoral growth.
# *   Charts on talent pool growth, internet penetration.
# *   Images of AI applications (smart farms, medical diagnostics, robots).
# *   Quotes from Indian AI leaders or policymakers.
#
# ### **Keywords for SEO:**
# AI in India, India AI, Artificial Intelligence India, Indian AI startups, NITI Aayog AI, AI policy India, AI healthcare India, AI agriculture India, Indian tech revolution, AI talent India, digital India AI, ethical AI India.

# %%
print(final_state["content"])   # final blog
# Out:
# ## Unlocking Potential: The Multifaceted Rise of AI in India
#
# While Artificial Intelligence (AI) reshapes industries worldwide, a silent yet profound revolution is brewing in the heart of the world's largest democracy – India. Far from being a mere spectator, India is rapidly emerging as a significant player in the global AI landscape, driven by a unique blend of digital infrastructure, a vast talent pool, and a strategic vision for inclusive growth.
#
# India's journey from a traditional, agrarian economy to a digital powerhouse has been nothing short of remarkable. The widespread adoption of the Unified Payments Interface (UPI), the biometric identification system Aadhaar, and an explosion in smartphone penetration have laid a robust digital foundation. This digital leap, coupled with a world-renowned IT services industry and a massive pool of engineering and science graduates, has created fertile ground for AI to flourish. This blog post will delve into the multifaceted rise of AI in India, examining its key drivers, diverse applications across critical sectors, the thriving ecosystem supporting its growth, the inherent challenges that must be addressed, and its immense future potential on both national and global scales.
#
# ### The Catalysts: Why Now?
#
# India's current embrace of AI isn't accidental; it's the culmination of several powerful forces converging, creating a perfect storm for innovation.
#
# #### A. Government Push & Policy Framework: The "AI for All" Vision
# At the forefront of India's AI ascent is a proactive government vision. NITI Aayog, the premier policy think tank of the Government of India, spearheaded the national strategy for Artificial Intelligence, aptly titled "National Strategy for Artificial Intelligence: #AIforAll." This vision emphasizes AI's potential for inclusive growth, focusing on leveraging AI to solve societal problems rather than just economic ones. Key initiatives include the National Programme on AI, designed to foster research and development, and "Responsible AI for Youth," aimed at building foundational AI literacy among students. The impending Data Protection Bill, while still evolving, underscores the government's commitment to creating a secure and ethical data environment, crucial for responsible AI deployment. Furthermore, significant efforts are underway to build robust compute infrastructure and data centers, recognizing them as the backbone of an AI-powered economy.
#
# #### B. A Deep & Diverse Talent Pool
# India boasts one of the world's largest pools of STEM graduates, producing millions of engineers and science professionals annually. This sheer volume provides a critical mass of potential AI talent. The nation's decades-long legacy in IT services has also created a strong foundation in software development, data management, and complex problem-solving—skills highly transferable to AI development. Recognizing the evolving demands, there's a significant push for upskilling and reskilling. The proliferation of AI/ML courses, certifications, and corporate training programs signifies a concerted effort to transform existing IT professionals and fresh graduates into AI-ready experts, ensuring a continuous supply of skilled personnel.
#
# #### C. Data-Rich Environment
# India's rapid digital transformation has inadvertently created one of the world's most data-rich environments. Platforms like UPI and Aadhaar generate colossal datasets daily, offering unparalleled opportunities for AI training and application. Jio's internet penetration, bringing affordable data to millions, further amplifies this data generation. Beyond sheer volume, India presents a unique challenge and opportunity due to its linguistic diversity. Developing multilingual AI models that can understand and process India's myriad languages (over 22 official languages and hundreds of dialects) is a significant frontier, paving the way for truly inclusive AI. Moreover, domain-specific data from sectors like healthcare, agriculture, and finance offers unique insights for specialized AI solutions tailored to Indian contexts.
#
# #### D. Thriving Startup Ecosystem & Investment
# The Indian startup ecosystem, particularly in tech, is booming, and AI is a major beneficiary. Venture Capital (VC) firms, both domestic and international, are showing growing interest, channeling significant investments into Indian AI startups. Government-backed and private incubation and acceleration programs are fostering innovation, providing crucial mentorship, funding, and infrastructure. We're witnessing the rise of prominent Indian AI startups across various domains – from SaaS solutions optimizing business processes to AI-powered diagnostics in healthcare and innovative fraud detection in fintech. These success stories are not only attracting more investment but also inspiring a new generation of AI entrepreneurs.
#
# ### AI in Action: Sectoral Impact & Applications
#
# The practical applications of AI in India are vast and varied, addressing both global challenges and unique local needs.
#
# #### A. Healthcare Transformation
# AI is poised to revolutionize India's healthcare landscape, particularly in bridging the urban-rural divide. AI-powered image analysis is enhancing diagnostics in radiology and pathology, enabling early and accurate disease detection, even in remote areas with limited specialist access. In drug discovery and development, AI is accelerating research, identifying potential drug candidates, and paving the way for personalized medicine tailored to individual genetic profiles. Telemedicine and remote care platforms, often augmented by AI for preliminary symptom analysis and predictive analytics for disease outbreaks, are becoming crucial for accessible healthcare.
#
# #### B. Revolutionizing Agriculture (Agri-Tech)
# Given India's agrarian roots, AI's impact on agriculture is transformative. Precision farming techniques, leveraging AI for crop yield prediction, pest and disease detection through drone imagery and sensor data, and hyper-local soil analysis, are empowering farmers with data-driven decisions. AI-driven supply chain optimization is reducing post-harvest waste and improving market access for farmers, ensuring better returns. Furthermore, AI-powered weather forecasting and advisory services provide crucial, timely information, helping farmers mitigate risks and optimize planting schedules.
#
# #### C. Financial Services (FinTech)
# The FinTech sector is a prime adopter of AI in India. AI algorithms are crucial for real-time fraud detection and robust risk assessment, protecting consumers and financial institutions. They also enable more accurate credit scoring for underserved populations, fostering financial inclusion. Personalized banking experiences, driven by AI chatbots and customized financial advice, are becoming commonplace. On the investment front, algorithmic trading and AI-driven insights are providing sophisticated tools for market analysis and portfolio management.
#
# #### D. Education & Skilling
# AI is personalizing the learning experience like never before. Adaptive platforms and intelligent tutoring systems can tailor content and pace to individual student needs, identifying learning gaps and providing targeted support. AI-assisted tools are also streamlining content creation and curation for educators. Administratively, AI is automating routine tasks, freeing up educators to focus more on teaching and student engagement.
#
# #### E. Language & Localization
# India's linguistic diversity presents a unique opportunity for AI. Significant strides are being made in developing multilingual AI models for India's diverse languages, powering voice assistants, real-time translation services, and natural language processing (NLP) applications. These advancements are enhancing customer service, enabling content moderation across various regional languages, and making technology accessible to a broader population.
#
# #### F. Smart Cities & Public Services
# In the burgeoning smart city initiatives, AI plays a vital role. Predictive analytics is optimizing traffic management by anticipating congestion and dynamically adjusting smart signaling. AI helps optimize waste management by identifying collection patterns and resource allocation. AI-powered chatbots are improving grievance redressal mechanisms, offering quick and efficient citizen services.
#
# ### The Ecosystem & Key Players
#
# The vibrant Indian AI ecosystem is a collaborative effort involving various stakeholders.
#
# #### A. Startups & Innovators
# Agile and often bootstrapped, Indian startups are at the forefront of AI innovation, particularly in addressing specific Indian problems. Major innovation hubs like Bengaluru, Hyderabad, Gurugram, and Pune are buzzing with AI activity, fostering a culture of rapid prototyping and deployment. These startups are creating niche solutions that are scalable and globally relevant.
#
# #### B. Corporate Giants
# India's established IT service companies—TCS, Infosys, Wipro, HCLTech—are not only adopting AI internally but also developing and deploying sophisticated AI solutions for their global clientele. Beyond IT, conglomerates like Reliance and the Tata Group are integrating AI across their diverse businesses, from retail and telecom to manufacturing and automotive, leveraging their vast resources to drive large-scale AI adoption.
#
# #### C. Academia & Research Institutions
# Premier institutions like the Indian Institutes of Technology (IITs), the Indian Institute of Science (IISc), and other leading universities are driving fundamental AI research and nurturing the next generation of AI talent. The formation of dedicated AI labs and centers of excellence within these institutions is fostering a strong academic foundation.
#
# #### D. International Collaborations
# India is also a hub for international collaborations, partnering with global tech giants and research institutions to advance AI capabilities. Foreign direct investment (FDI) continues to flow into the Indian AI sector, signaling global confidence in India's potential.
#
# ### Challenges & Ethical Considerations
#
# Despite its rapid ascent, India's AI journey is not without hurdles.
#
# #### A. Data Quality & Availability
# While India has abundant data, issues persist with fragmented, unstructured, or biased datasets. A significant challenge lies in ensuring high-quality, labeled data for training robust AI models. There's a pressing need for better data governance, standardization, and interoperability across various public and private datasets.
#
# #### B. Infrastructure & Compute Power
# Access to high-performance computing (HPC) infrastructure remains a bottleneck, particularly for smaller startups and research institutions. Reliable and high-speed internet connectivity, especially in rural and semi-urban areas, is also crucial for deploying and accessing AI-powered services effectively.
#
# #### C. Talent Gap & Upskilling
# Despite the large number of STEM graduates, a shortage of specialized AI researchers, data scientists, and machine learning engineers persists. Continuous efforts are needed for upskilling the existing workforce and integrating practical AI education into mainstream curricula to meet the surging demand.
#
# #### D. Ethical AI & Bias
# Addressing algorithmic bias in AI systems, especially when trained on diverse Indian populations with varying socio-economic backgrounds, is paramount. Ensuring fairness, transparency, and accountability in AI applications is crucial to prevent discrimination and build public trust. Privacy concerns and robust data security measures are also central to the ethical deployment of AI.
#
# #### E. Regulatory Framework
# Developing a comprehensive and agile regulatory framework that fosters innovation while ensuring safety, privacy, and ethical compliance is a delicate balancing act. India's approach to AI regulation will significantly shape its future trajectory.
#
# #### F. Job Displacement vs. Creation
# The societal impact of automation, particularly potential job displacement in certain sectors, is a concern. The focus must be on anticipating these changes and proactively investing in reskilling programs to facilitate new job creation and prepare the workforce for an AI-augmented future.
#
# ### The Road Ahead: India's AI Future
#
# India's AI journey is still in its early chapters, but the vision for the future is clear and ambitious.
#
# #### A. "AI for Bharat": Inclusive Growth
# The core tenet of "AI for Bharat" will continue to drive India's AI strategy. The focus will remain on solving India-specific problems such as poverty alleviation, improving healthcare access, enhancing educational outcomes, and building climate resilience. Leveraging AI for inclusive growth and social impact will ensure that the benefits of this technology reach every corner of the nation.
#
# #### B. Global AI Leadership
# India has the potential to become a global hub for AI innovation, particularly in responsible and ethical AI. Its diverse population and commitment to inclusive growth position it uniquely to develop and champion AI solutions that are fair, transparent, and beneficial for all. India could emerge as a significant exporter of AI solutions and expertise, especially to other developing nations facing similar challenges.
#
# #### C. Emerging Technologies
# The future will see deeper integration of AI with other emerging technologies like Quantum Computing, the Internet of Things (IoT), and Web3.0. There will be an increased focus on Explainable AI (XAI) to ensure transparency in decision-making and the development of Trustworthy AI systems that are robust, secure, and reliable.
#
# #### D. Policy Evolution
# Continued government support, agile policy-making that adapts to rapid technological advancements, and strong public-private partnerships will be critical. These collaborations will accelerate research, facilitate infrastructure development, and ensure a conducive environment for AI innovation.
#
# ### Conclusion
#
# India's journey in the realm of Artificial Intelligence is a compelling narrative of innovation, strategic foresight, and immense potential. From a robust digital foundation and a vast talent pool to proactive government policies and a thriving startup ecosystem, the catalysts for AI's rise are firmly in place. Its applications are already transforming critical sectors, promising to uplift millions and address long-standing societal challenges.
#
# While challenges such as data quality, infrastructure, and ethical considerations demand careful navigation, India's commitment to "AI for All" positions it uniquely to foster inclusive and responsible AI development. The rise of AI in India isn't just a technological leap; it's a societal transformation poised to redefine the future for a billion people and beyond, cementing India's role as a responsible AI leader on the global stage. The journey has just begun, and the world watches as India harnesses AI to unlock unprecedented potential.
